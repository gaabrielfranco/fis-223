# %% [markdown]
# # Primeiro Relatório de FIS225 - Circuíto RC

# %% [markdown]
# ## Objetivos

# %% [markdown]
# O objetivo dessa atividade prática é verificar como a diferença de potencial de um capacitor varia em função do tempo, especificamente quando o mesmo é sujeito ao processo de descarga. Além disso, espera-se que a interpretação do significado do produto da resistência pela capacitância em um circuito RC, bem como sua importância em aplicações tecnologicas, sejam esclarecidas.

# %% [markdown]
# ## Intro

# %% [markdown]
# Espaço para intro (Gabriela)

# %% [markdown]
# ## Materiais

# %% [markdown]
# + Placa de circuito Vernier, com chave S
# + Capacitor com capacitância igual a 10 microF
# + Resistores de resistência igual a 22 kOhm, 47 kOhm e 100 kOhm
# + Interface Vernier com sensor de voltagem
# + Computador com os programas Logger Pro e <Programa de gráfico que esqueci o nome> instalados corretamente

# %% [markdown]
# ## Metodologia

# %% [markdown]
# A. Monte o circuito de acordo com o mostrado na figura 2, com chave S voltada para cima, isto é, para carregar o capacitor, usando a resistência de 100 kOhm.
#
# B. Conecte a fonte de alimentação ao circuito e o sensor de voltagem em paralelo com capacitor. Conecte este sensor à interface Vernier que se conecta ao computador. Ligue o computador e a interface e inicie o programa "Logger Pro". Ao iniciar o programa, verifique que aparecerá um gráfico de voltagem em função do tempo e também uma leitura instantânea da voltagem referente ao sensor. Zere a leitura do sensor de voltagem para calibrar o sistema clicando no ícone "zero".
#
# C. Ajuste a tensão da fonte lentamente até, no máximo, 5.0 V, até o indicador de voltagem no programa (computador) indique um valor próximo e menor que 5.0 V.
#
# D. Verifique, no computador, a curva de descarga do capacitor clicando no ícone "Collect" do programa Logger Pro e deslocando a chave S para baixo, ou seja, modo de descarga do capacitor.
#
# E. Selecione no gráfico gerado a parte correspondente à descarga e copie da tabela de dados 10 pontos igualmente espaçados, correspondentes à diferença de potencial e ao respectivo tempo, nas tabelas abaixo. Repita o procedimento usando os resistores de 47 kOhm e 22 kOhm.
#
# F. Usando um único papel semi-logaritmo plote V(t) X t para os 3 resistores utilizados, demarcando os pontos no papel de formas e cores diferentes para cada resistor. Encontre a constante de relaxação Tau para cada um dos sistemas RC utilizados no experimento - Lembre-se de calcular um fator de escala que permita construir os 3 gráficos em boas dimensões. Isso diminui seu erro ao traçar a melhor reta.
#
# G. Calcule diretamente Tau a partir de sua definição e estime o erro experimental de acordo com seus resultados obtidos no item F.
#
# H. Provavelmente seu erro ficou maior para o resistor 22 kOhm. Qual é a sua justificativa? Dica: Relacione sua resposta com Tau para esse sitema.
#
# I. Reescreva (7) e (8) em termos do potencial da bateria.
#
# J. A constante 1/RC que encontramos acima tem unidade de qual grandeza?
#
# K. Baseado na sua resposta para o item 2, qual é o tempo (Tau) necessário para que o potencial no capacitor caia para aproximadamente 63,3% do seu valor original? (Tau é conhecido como tempo de relaxação - e lembre-se que 1/e ~ 0,367

# %% [markdown]
# ## Resultados experimentais e Discussão

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (25, 16)
plt.rcParams['font.size'] = 18.0

Resistor22k = pd.read_csv('data/Resistor 22k.csv')

Resistor22k.plot(x='Time', y='Potential', logy=True, title="Gráfico de potencial por tempo usando o resistor de 22k")

# %%
Resistor47k = pd.read_csv('data/Resistor 47k.csv')

Resistor47k.plot(x='Time', y='Potential', logy=True, title="Gráfico de potencial por tempo usando o resistor de 47k")

# %%
Resistor100k = pd.read_csv('data/Resistor 100k.csv')

Resistor100k.plot(x='Time', y='Potential', logy=True, title="Gráfico de potencial por tempo usando o resistor de 100k")

# %% [markdown]
# ## Conclusão

# %% [markdown]
# ## Referências Bibliográficas
